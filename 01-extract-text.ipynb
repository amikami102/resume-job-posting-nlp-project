# %% [markdown]
# # Objective
#
# Extract relevant sections from the job posting html files.

# %%
import pathlib
from bs4 import BeautifulSoup 

cur_path = pathlib.Path()
data_path = cur_path.joinpath('data', 'html_job_postings')
html_files = data_path.iterdir() # iterator of html files

# %% [markdown]
# # Extract relevant texts from html

# %%
def extract_text(html): 
    """
    Extract position title and job requirements from job positng html. 
    """
    with open(html, "r", encoding = "utf-8") as h:
        html_content = h.read()
    
    soup = BeautifulSoup(html_content)
    title = soup.find('title').text
    position, *location = title.split(" - ")

    if len(location) == 2:
        company, location = location 
    else:
        company, location = None, location[0]

    body = soup.find('body')
    if body.find('li'):
        jobreq = [bullet.text for bullet in body.find_all('li')]
    else:
        jobreq = [bullet.text for bullet in body.find_all('p')]
    
    return {'html': html,
            'position': position,
            'location': location,
            'company': company, 
            'jobreq': ' '.join(jobreq).strip('\n').replace('\n', '')}

# %%
data = []
for html in html_files:
    data.append(extract_text(html))

# %%
import pandas as pd 

df = pd.DataFrame(data)
print(df.info())
print(df.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1337 entries, 0 to 1336
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   html      1337 non-null   object
#  1   position  1337 non-null   object
#  2   location  1337 non-null   object
#  3   company   244 non-null    object
#  4   jobreq    1337 non-null   object
# dtypes: object(5)
# memory usage: 52.4+ KB
# None
#                                                 html  \
# 0  data/html_job_postings/1e92960a19ffdd34_fccid....
# 1  data/html_job_postings/3157fcef3ee474da_fccid....
# 2  data/html_job_postings/b423ca22a6e2c10f_fccid....
# 3  data/html_job_postings/ea487254a487beb5_fccid....
# 4  data/html_job_postings/cb8a5bce330854e9_fccid....
#
#                                             position             location  \
# 0                               Quantitative Analyst     Boston, MA 02116
# 1                                     Data Scientist    Mountain View, CA
# 2                                     Data Scientist          Seattle, WA
# 3  Senior Natural Language Processing (NLP) Engineer           Boston, MA
# 4                            FLEXO FOLDER GLUER OPER  McClellan, CA 95652
#
#          company                                             jobreq
# 0           None  Quantitative Analyst (State Street Bank and Tr...
# 1           None  Help senior members of the team to explore, de...
# 2           None  A Bachelor or Masters Degree in a highly quant...
# 3           None  Join a small team creating a proprietary NLU s...
# 4  McClellan, CA  At Packaging Corporation of America (PCA), we ...

# %%
df.loc[0, 'jobreq']
# Out:
# 'Quantitative Analyst (State Street Bank and Trust Company; Boston, MA): The Quantitative Analyst will be part of State Street Treasury’s Treasury Quantitative Analytics (TQA) group. TQA is responsible for developing/implementing/monitoring advanced financial models that are used in company’s capital management, liquidity management, investment portfolio construction, and balance sheet optimization. The group is accountable for in-depth understanding, modeling, and representation of the complex interaction of global markets, customer behaviors, and regulatory oversights to create a view of risk/revenue opportunities and exposures to the investment committee, Board of Directors, senior management, and regulatory agencies. The Quantitative Analyst role is a key contributor to the realization of the GT’s mission of optimizing net interest income within the desired risk appetite position. Specific responsibilities include: apply advanced statistical techniques to analyze the characteristics of the bank’s liabilities (including deposit balance forecast, deposit attrition rate and deposit pricing), using time-series analysis, survival analysis, and non-parametric regressions; experience with machine learning techniques such as principal component analysis, regression trees, and non-linear models; conduct in-depth quantitative analysis on how macroeconomic changes impact the bank’s balance sheet positions and understand the interest rate risks of the bank in different economic cycles; apply solid knowledge of CCAR, DFAST, and Basel regulations and developed stress testing models to quantify capital and liquidity risks; create and maintain model documentation that meets corporate model risk standards including model development and implementation papers; ensure proper ongoing monitoring of model performance including back-testing and performance reviews; and work closely with key business partners and senior management to understand the business needs and conditions and determine the analytical tools and data needed; serve as the subject matter experts on product analysis and modeling with regulatory agencies and internal oversight functions.  Minimum requirements: Master’s degree in Econometrics, Mathematics, Statistics, or a related quantitative field plus 2 years of quantitative modeling experience including at least one year in a large, complex financial institution with a broad exposure to all lines of businesses of a custodial bank.  Must have: demonstrated experience modeling complex financial concepts using non-linear, error correction, survival, and time-series models, Monte Carlo simulations and unsupervised and supervised machine learning, and other advanced quantitative techniques; proven knowledge of liquidity and capital stress testing, CCAR, and deposit modeling experience required; proven solid ability working with large and complex data sets including relational databases and complex queries using both SQL Server and My SQL; demonstrated proficiency in R/SAS/Matlab coding and working knowledge of Excel VBA, Eviews, python, and Cloudera Data Science Workbench; deep and broad understanding of all kinds of financial instruments like loans and deposits, as well as derivatives like options and futures; CFA candidates desired; demonstrated strong written and verbal communication skills and ability to present material to various audiences including upper management and regulators; and proven ability to take initiative, adapt and learn quickly, and be a self-starter. (Unless otherwise indicated, State Street is seeking the ability in the skills listed above with no specific amount of experience required. All experience can be gained concurrently).  A pply online at statestreet.com/careers . State Street Job ID: R-620670 . An EOE.  “#LI-DNI”'

# %% [markdown]
# # Remove job postings unrelated to data scientist position

# %%
df['position'] = df['position'].map(lambda p: p.lower())
print(df['position'].unique())
# Out:
# ['quantitative analyst' 'data scientist'
#  'senior natural language processing (nlp) engineer'
#  'flexo folder gluer oper' 'junior data scientist' 'business analyst'
#  '(entry-level) data scientist' 'data scientist, analytics'
#  'data scientist intern' 'software engineering intern'
#  'data scientist bslef8' 'computational biologist' 'quality engineer'
#  'chief data scientist' 'data science manager' 'data science intern'
#  'real estate development manager' 'healthcare data analytics'
#  'research statistician' 'staff assessor-pca (entry level)' 'manager'
#  'bioinformatics data scientist' 'financial representative'
#  'lead data scientist' 'data engineer' 'test automation engineer'
#  'software developer – machine-learning/artificial-intelligence'
#  'senior data consultant' 'postdoctoral scholar'
#  'research engineer – deep learning and generative design'
#  'biostatistician i'
#  'senior architect, corporate social responsibility platform'
#  'statistical analyst' 'senior data scientist' 'epidemiologist'
#  'pt off hours es advocate job description' 'clinical data analyst'
#  'financial advisory services complex financial instruments experienced associate'
#  'lead of imaging ai' 'sr. research data analyst' 'data analyst'
#  'language engineer'
#  'optimization and kyc model risk analyst, associate/avp'
#  'data science and analytics internship' 'data science consultant'
#  'senior machine learning (ml) and computer vision (cv) engineer'
#  'director of marketing' 'chief data officer' 'data engineer, sales'
#  'data bi analyst' 'tdi' 'senior data analyst'
#  'data analytics instructor, ut austin'
#  'research scientist, digital wellbeing' 'algorithm developer'
#  'software developer–natural language processing' 'page not found'
#  'corporate control management'
#  'machine learning engineer : natural language processing'
#  'precision health data sciences and informatics faculty'
#  'director of data science and analytics' 'product data scientist'
#  'swe data scientist' 'pwc labs'
#  'computational sciences undergraduate internship program'
#  'product analyst, caviar' 'data engineer, infrastructure strategy'
#  'financial advisory services complex financial instruments senior associate'
#  'data consultant' 'principal heor and pharma analytics'
#  'deal desk analyst' 'certified nursing assistant pca pcu surgical'
#  'director, predictive modeling' 'data scientist, engineering'
#  'machine learning engineer (nlp)' 'talend automation spoc'
#  'epidemiologist-health informatics and evaluation'
#  'data analyst (part-time)'
#  'analyst, quantitative software developer (san francisco)'
#  'research analyst' 'front end engineer'
#  'investment banking and equity summer intern (la)'
#  'applied research scientist, natural language processing'
#  'staff data scientist' 'research assistant iv'
#  'manager, natural language processing data scientist'
#  'industrial engineer university grad' 'product data scientist, lenses'
#  'certified nursing assistant pca' 'manager/ principal data analyst'
#  'engineering manager – apple maps search' 'data engineer – logs'
#  'research scientist, mobile manipulation perception'
#  'sr. associate, data scientist, natural language processing'
#  'social network analysis and document generation' 'account clerk i/ii'
#  'clinical data scientist' 'patient care associate' 'product manager'
#  'data scientist (financial services)' 'data scientist in broomfield, co'
#  'siri' 'fas valuation services director' 'business insights analyst'
#  'data scientist i'
#  'data scientist â€“ machine learning and human machine teaming'
#  'principal data scientist' 'consulting data analyst'
#  'associate data scientist' 'quantitative consumer and product modeler'
#  'database architect'
#  'transaction advisory services- complex securities- senior'
#  'linguist (chinese)' 'jd digits' 'advanced media analytics'
#  'sales executive' 'configuration management specialist'
#  'biological data scientist'
#  'data scientist, media and advertising analytics'
#  'personal care assistant' 'director' 'police crime analyst (7716)'
#  'research intern' 'service advisor' 'actuarial analyst ii'
#  'employee experience (ex) insights and analytics partner'
#  'data analyst e-commerce' 'staff engineer' 'recruiter'
#  'wellness promoter: part-time' 'quality assurance manager'
#  'business analyst, business planning and operations' 'applied scientist'
#  'data scientist population health' 'data scientist (c13/vp) new york, ny'
#  'data liaison' 'engineering intern, system modeling and characterization'
#  'operations research intern' 'intern'
#  'director, experimental design and measurement'
#  'nasa smaec data scientist' 'npi engineer'
#  'machine/deep learning data scientist' 'data analytics intern'
#  'records & data management specialist i'
#  'data science consultant, engineering support analytics, google cloud'
#  'product analyst' 'kafka developer with python' 'internship'
#  'direct care' 'director, delivery services' 'quality engineering intern'
#  'software scaleout and optimization engineer'
#  'applied machine learning scientist' 'sr data scientist.'
#  'internship opportunities for students: data & applied sciences'
#  'data analytics teaching assistant' 'principal, geo-statistics'
#  'analytics, ww sales finance' 'cp&s data and insights analyst'
#  'software engineer'
#  'senior principal reliabilty engineer / secret / interim secret'
#  'data scientist san francisco, ca' 'patient care clerical coord'
#  'consultant' 'research data curator (librarian 2)'
#  'machine learning engineer' 'audit manager' 'jr. data scientist'
#  'research scientist, machine learning and intelligence' 'sales engineer'
#  'operations insights and impact analyst, youtube'
#  'tire modelling engineer ii' '2019-57 sr. data scientist'
#  'full time opportunities for students or recent graduates: data & applied sciences'
#  'intelligence analyst 2' 'cyber'
#  'data governance and privacy domain expert' 'data science engineer iii'
#  'summer big data analyst' 'merchandise presentation intern'
#  'quantitative researcher' 'leadership partner, data and analytics'
#  'machine learning intern (ml-agents), ai@unity' 'summer intern'
#  'sr manufacturing engineer' 'portfolio risk officer'
#  'data science instructor' 'data analyst i' 'sr. test technician'
#  'operations research analyst' 'field data scientist'
#  'field scout, wonderful orchards'
#  'intelligence analyst counter terrorism (targeting)'
#  'software product manager, framework and applications'
#  'cellular power & performance engineer' 'technology spring 2020 intern'
#  'open source staff machine learning engineer' 'intern, data science'
#  'senior full stack web engineer' 'oracle dba'
#  'associate management analyst/management analyst (apply by friday, n (19931735)'
#  'stress analyst ii' 'lead data scientist, peacock, direct-to-consumer'
#  'data analyst and data scientist' 'post-doctoral scientist'
#  'financial advisory services valuation senior associate'
#  'data scientist senior' 'institutional data and research analyst (6948u)'
#  'senior software engineer_idm' 'data scientist director'
#  'machine learning researcher, ai research' 'product analyst, growth'
#  'director of marketing statistics' 'supply chain specialist 1'
#  'data analytics instructor' 'data scientist (analytic consultant 4)'
#  'global data engineer' "class of '67 leadership research fellow"
#  'software engineer, probability' 'account manager west'
#  'patient care assistant, surgical (gynecology/urology) unit'
#  'staff ml engineer' 'data scientist, applied machine learning'
#  'infrastructure engineer ii' 'supplier quality engineer' 'staff nurse ii'
#  'machine learning intern' 'maintenance leadperson~si4241~5204'
#  'clinical data analyst (intern)' 'research student' 'ideo u and openideo'
#  'part-time instructor of statistics for data science and machine learning'
#  'diagnostic technician 1' 'mid-level software engineer_idm'
#  'unmanned carrier aviation (uca) (55-8009)' 'data scientist (analytics)'
#  'engineer i (plant optimization)' 'software engineer, data pipelines'
#  'applied data ethics fellow' 'valuation services senior associate'
#  'interlibrary projects assistant (6760c) 27525' 'statistician'
#  'machine learning' 'ew operations analyst'
#  'natural language processing data scientist- audit'
#  'data and evaluation specialist' 'geochemistry postdoctoral fellow'
#  'natural language processing and machine learning engineer'
#  'data scientist, principal/sr. principal' 'computer vision scientist'
#  'postdoctoral position – cheminformatics team' 'brand consultant'
#  'linguist intern, summer 2020'
#  'product director, personalization science'
#  'data science health innovation fellow job'
#  'capital work readiness analyst (career)'
#  'product engineer – spatial data science and statistical analysis'
#  'impact and learning manager'
#  'data scientist / natural language processing (nlp)'
#  'mechanical research engineer' 'junior analyst' 'python engineer'
#  'siri language engineer' 'veterans certifying official' 'researcher'
#  'patient care assistant / pca' 'dsi instructor lead'
#  'natural language processing undergraduate intern- summer 2020'
#  'senior data scientist, vsp vision care' 'it data scientist'
#  'data science lead' 'data scientist manager'
#  'accounting support specialist'
#  'data scientist/ machine learning engineer'
#  'assistant research professor, computational simulation of social behavior'
#  'ied and insurgent network analyst' 'data science, assoc. director'
#  'clerk patient care assistant- endoscopy suite' 'manager, data sciences'
#  'scientific programmer' 'data scientist midlevel' 'master scheduler'
#  'ui engineer' 'assistant professor'
#  'people research scientist, internal communications'
#  'quality systems specialist' 'scientist i, bioinformatics'
#  'healthcare data analyst' 'mathematical statistics series' 'scorekeeper'
#  'research post doctoral fellow' 'regional sales manager-5' 'qa associate'
#  'director payments north america' 'bilingual research assistant'
#  'ai research engineer – natural language processing'
#  'full stack python data engineer'
#  'data analyst and compliance specialist'
#  'senior analyst, engagement & retention analytics, peacock'
#  'sigint dni analyst'
#  'summer 2020 data reporting internship at the wall street journal'
#  'data science summer institute student intern'
#  'statistics / data science (early/mid-career)' 'lead platform engineer'
#  'supply chain specialist 3' 'senior consulting data analyst'
#  'data scientist (phd)' 'senior associate' 'junior software engineer_idm'
#  'senior computer vision engineer' 'data/nlp scientist'
#  'predictive analyst i' 'patient care assistant, acute rehab unit'
#  'cloud comp engr associate' 'hourly research assistant'
#  'asset managmenet analyst' 'systems engineer'
#  'process & automation engineer' 'data architect'
#  'research associate in data analytics and natural language processing'
#  'principal machine learning engineer' 'manager / senior manager'
#  'associate, data science and client analytics'
#  'vsan member of technical staff' 'stock / forex trader'
#  'market data business analyst' 'full stack engineer'
#  'ssmc-staff nurse ii' 'air quality technician i/ii'
#  'environmental, health and safety specialist iii'
#  'business intelligence analyst' 'senior big data java engineer'
#  'global strategic insights lead' 'data and reporting analyst'
#  'research scientist, computational genomics (single cell characterization)'
#  'siri rotational program'
#  'open level professor, statistics for data science'
#  'juvenile institution officer i'
#  'data processing senior research scientist, opir'
#  'data scientist, analytics (university grad)'
#  'preservation assistant, library' 'marketing impact director'
#  'summer 2020 data science internship at the wall street journal'
#  'data analyst, customer support' 'director, data science'
#  'data scientist, insights' 'industrial engineering'
#  'crisis mapping and data science specialist' 'analyst'
#  'data scientist-remote'
#  'research scientist, computational social science (phd)'
#  'python systems engineer' 'data analyst internship'
#  'transaction advisory services- valuation modeling & economics- complex securities- senior'
#  'data & tableau reporting analyst'
#  'data scientist, predictive modeling and analytics'
#  'data scientist (machine learning)' 'sr. predictive analyst'
#  'post doctoral fellow' 'sr director of data science'
#  'performance improvement consultant' 'senior data analyst, marketing'
#  'sr. data scientist' 'digital network intelligence analyst'
#  'support data analyst' 'insurance data scientist'
#  'web application developer, engineering data'
#  'post-doc: dissemination/implementation and/or data science and/or sleep research'
#  'cyber intelligence analyst' 'quantitative business analyst, geo'
#  'health and human services technician i- bilingual (spanish preferred)'
#  'senior consultant, financial services'
#  'sr. data and machine learning specialist' 'weather data specialist'
#  'temporary data analyst and visualization specialist, center for digital and data excellence'
#  'silicon valley engagement program manager' 'patient care asst'
#  'admissions associate pt' 'junior statistician'
#  'data analytics manager, royalties and accounting'
#  'statistics content author'
#  'autonomous driving engineer – advanced tracking and sensor fusion'
#  'production manager' 'senior data scientist / machine learning engineer'
#  'srspec, model dev'
#  'sr. lead data scientist, peacock, direct-to-consumer'
#  'product manager, oodapay'
#  'manager- financial consulting valuation services'
#  'data scientist – statistics and machine learning (phd)'
#  'process quality engineer' 'linguist (russian)' 'data scientist ii'
#  '2020 intern' 'account excecutive' 'wellness promoter'
#  'machine learning software engineer' 'research intern, 2020'
#  'assistant teaching professor-statistics'
#  'director of econometric modeling' 'flexo folder gluer asst'
#  'undergrad summer internship' 'data analyst, analytics and research'
#  'machine learning engineer, marketplace'
#  'senior software engineer, roku content pipeline integrity and data quality'
#  'director, data engineering' 'principal ee' 'senior engineer (software)'
#  'admin, bookkeeper' 'senior quantitative modeler (san francisco, ca)'
#  'data scientist, media manipulation' 'data astronaut' 'actuarial analyst'
#  'project cost controls analyst-pca' 'assistant director,\xa0data center'
#  'data intelligence analyst' 'senior data scientist, education'
#  'data scientist and designer'
#  'senior linguist, assistant natural language understanding'
#  'machine learning / data scientist internship (summer 2020)'
#  'patient transportation specialist prn'
#  'associate and experienced data scientists'
#  'computer science and engineering: assistant professor in deep learning'
#  'data & applied scientist' 'machine learning postdoctoral fellow'
#  'principal data scientist – analytics lab'
#  'ml/data science intern (summer 2020)' 'analytical lead'
#  'decision science manager (facebook app)' 'linguist/language analyst'
#  'data scientist 2 or 3' 'head of applied science'
#  'risk, model risk management, model validation, analyst, dallas'
#  'data science internship' 'analyst intern'
#  'associate computational biologist'
#  'health services data & reporting analyst'
#  'research and consulting analyst' 'data scientist 2/3'
#  'ba-data analystics & visualization'
#  'nursing assist,icu/ccu,15117,36 hrs-7a-7:30p,eow'
#  'manager, valuation and litigation services'
#  'beyonders 2020 summer program'
#  'merrill lynch wealth management data scientist'
#  'staff nurse ii -medical surgical-eve-benefitted'
#  'postdoctoral researcher' 'manager, major projects advisory'
#  'senior spss advanced business analytics consultant'
#  'data center engineer 2' 'tg shift supervisor' 'pca'
#  'dean, mathematics, statistics and engineering'
#  'natural language processing and machine learning scientist'
#  'project manager' 'data scientist, entity resolution and data linking'
#  'lead of clinical ai' 'blockchain analyst' 'data and policy analyst'
#  'staff applied machine learning engineer'
#  'associate analyst, mastercard launch 2020'
#  'languages and compiler engineer' 'summer 2020 intern'
#  'deep learning engineer' 'senior data engineer'
#  'manager, data sciences machine learning' 'sql database administrator'
#  'guild advisor'
#  'natural language processing and machine learning tech lead'
#  'walmart retail link associate'
#  'analyst, applied data and machine learning'
#  'store assistant (non-bonused)' 'entry level'
#  'assistant professor in statistics, applied probability, and data science'
#  'ecommerce senior data scientist'
#  'environment, health and safety specialist' 'applied social scientist'
#  'data scientist, growth data science' 'quality engineer senior'
#  'store assistant (bonused)' 'nurse rn' 'analytical linguist'
#  'patient care assistant i (pca)' 'data visualization intern'
#  'ground systems engineer' 'supervisor' 'geospatial software developer'
#  'principal research engineers' 'social network analyst'
#  'tenure track teaching faculty position – statistics and data science – department of statistics and applied probability'
#  'associate staff scientist' 'workforce development data analyst'
#  'senior associate- financial consulting valuation services'
#  'senior analyst' 'marketing analytics manager'
#  'natural language processing graduate intern- summer 2020'
#  'data science specialist' 'natural language processing engineer'
#  'misinformation data analyst, community operations' 'netp trainer'
#  'lead engineer, ate test and characterization' 'fullstack engineer'
#  'full stack web engineer' 'production analyst'
#  'senior manager advanced analytics'
#  'research intern – applied sciences group' 'test engineer i'
#  'senior backend engineer' 'rhel integrator' 'snf nurse'
#  'dev ops engineer aws' 'nesap for data postdoctoral fellow'
#  'senior policy researcher' 'ecommerce data science intern'
#  'data scientist / ml engineer' 'engineering data scientist'
#  'senior quantitative analyst' 'systems engineer, w/poly'
#  'principle quality engineer'
#  'western crop research manager, sacramento area'
#  'senior business technical analyst' 'management analyst-contracts'
#  'targeting threat network analyst 2' 'predictive modeler intern'
#  'member of technical staff, devops engineer'
#  'interlibrary projects assistant' 'data analyst, growth' 'sr. analyst'
#  'software engineer, big data analytics' 'hrsc specialist iv'
#  'quantitative analyst-football operations' 'tutor or teacher'
#  'data science qa engineer' 'physics data scientist'
#  'professor of data sciences and operations (open rank)-statistics'
#  'entry-level data analysts' 'data scientists needed in ny'
#  'assistant/associate adjunct faculty in business analytics'
#  'travel demand modeler' 'engagement management associate'
#  'applied science intern, speech & language technology'
#  'research scientist in natural language processing'
#  'internship opportunities for phd students: data & applied sciences'
#  'die cutter assistant' 'data scientist: deep learning & nlp'
#  'senior manager of analytics' 'journeyman targeting network analyst'
#  'pca quality assurance reviewer #776' 'epidemiologist ii – dep, cphe'
#  'data scientist, integrity' 'biostatistician' 'automation spoc'
#  'certified nursing assistant pca peds icu'
#  'officer, planning & evaluation'
#  'data scientist, peacock, direct-to-consumer' 'associate'
#  'data engineer – systems and configuration' 'sr data analyst'
#  'hr/controller dual' 'manager, data analytics'
#  'patient attendant safety, ft, days' 'real estate analyst'
#  'data and applied scientist' 'data analyst/data scientist (2020 start)'
#  'financial advisory, valuation services manager'
#  'data scientist – machine learning, nlp and imageexpert'
#  'engineer/scientist'
#  'open-rank teaching faculty positions in artificial intelligence and data sciences'
#  '2020 phd data scientist internship' 'principal statistician'
#  'jo. equipment specialist' 'ai research scientist'
#  'data scientist, models and algorithms' 'rn'
#  'associate data scientist (bs / ms)'
#  'machine learning researcher / computational neuroscientist'
#  '2020 summer intern: modeling analyst'
#  'manager, data scientist, natural language processing (nlp)' 'pca intern'
#  'head, metabolomics knowledge center' 'phd data science intern'
#  'intelligence algorithms engineer, nest' 'data entry clerk, claims'
#  'data scientist i-iii' 'bioinformatics analyst i'
#  'privacy data scientist' 'principal pm manager' 'jr. data analyst'
#  'program manager' 'data scientist, mid' 'technical trainer'
#  'postdoctoral appointee' 'v.i.e.'
#  'engineering intern, model-based development' 'data scientist-dallas,tx'
#  'senior data scientist/r&d' 'academic personnel & hr coordinator (7715u)'
#  'vsan staff engineer' 'technical research analyst'
#  'data scientist / applied mathematician'
#  'sr. associate, natural language processing data scientist'
#  'senior manager/director, data protection alliances'
#  'social/behavioral sciences' 'data scientist for materials science'
#  'user experience research intern, summer 2020'
#  'director of program monitoring and evaluation'
#  'computational linguist, google assistant (natural language understanding)'
#  'engineering manager' 'data analyst- data science & analytics'
#  'full stack software engineer' 'senior machine learning engineer (nlp)'
#  'analytical chemist' 'data scientist iii'
#  'business planning and operations associate' 'ai & data' 'cimd'
#  'director of growth analytics' 'bioinformatics engineer, production'
#  'misc labor (burley, idaho)'
#  'applied scientist, natural language processing'
#  'capital and liquidity management' 'data science intern (summer 2020)'
#  'director, data scientist, natural language processing'
#  'technical information specialist (web services)'
#  'avmed junior data scientist' 'view & apply' 'project controls analyst'
#  'principal data scientist, natural language processing'
#  'research data analyst, global disease epidemiology and control'
#  'research post doctoral fellow (social determinants and cancer survivorship)'
#  'fuel pricing analyst' 'senior data visualization scientist'
#  'senior full stack developer' 'data analyst ii (sql/etl/statistics)'
#  'data scientist, natural language processing (nlp), descriptive statistics, statistical modelling, machine learning'
#  'data scientist, regulation, evaluation, and governance lab (reglab), stanford law school'
#  'senior data systems analyst (0599u)'
#  'journeyman weapons technical intelligence'
#  'director workplace violence mitigation' 'clinical data engineer'
#  'quality assurance engineer'
#  'new graduate – enterprise data & analytics – data science analyst'
#  'short-term casual' 'data scientist, bittorrent speed'
#  'senior data engineer (java and python)' 'data entry clerk'
#  'operations research scientist' 'xvantage group project manager'
#  'supplier development quality engineer sr.'
#  'business analyst, engineering support analytics, google cloud'
#  'senior/staff data scientist' 'consultant sales strategy'
#  'research programmer i' 'jr. data engineer' 'senior statistician'
#  'intelligence analyst' 'r&d bioinformatics scientist, ngs'
#  'member of technical staff, security engineer'
#  'quality data scientist, analytics'
#  'full time opportunities for phd students or recent graduates: data & applied sciences'
#  'machine learning/data science engineer'
#  'customer data scientist/sales engineer (bay area)'
#  'associate management analyst/management analyst'
#  'quality engineer (electronic industry)' 'accounting associate'
#  'campus recruiting: full time data scientist/data analytics (data analyst 2'
#  'qsr store assistant'
#  'financial advisory services complex financial instruments manager'
#  'data consultant (sas, r, python)'
#  'research manager & operations lead, fair'
#  'business analyst, google play apps and games'
#  'vsan senior member of technical staff' 'media mix modeler'
#  'principal machine learning and big data engineer'
#  'computational chemist' 'sr. data scientist(nlp)'
#  "associate director for strategic projects in the dean's office"
#  'sr. quality engineer (gtf)' 'research data analyst'
#  'staff software engineer' 'jit compiler engineer'
#  'senior software airworthiness engineer (2019-0923-d177)'
#  'fda data science and visual analytics fellowship'
#  'senior director of data science' 'sr. actuarial consultant'
#  'senior front end engineer' 'data science analyst'
#  'epidemiology data specialist (part-time)'
#  'business reporting and data analyst'
#  'software engineer, audio and signal processing'
#  'metrics and data manager' 'manager advanced analytics'
#  'sr. analyst, trust and safety' 'research associate'
#  'associate/full professor' 'analytics, retail marketing analyst'
#  'director of data, ai@unity' 'senior supplier development engineer'
#  'operations manager' 'bioinformatics associate data scientist'
#  'mid. discovery analyst'
#  'solution strategist, consultant (clinical optimization)'
#  'data analyst (6256u) 1737'
#  'data scientist, infrastructure strategy intern'
#  'machine learning and computer vision engineer (multiple levels)'
#  'machine learning intern (summer 2019)'
#  'data specialist, product support operations'
#  'social/data scientist, military personnel analytics team'
#  'special operations forces (sof) intelligence integrator (all teammates)'
#  'full-stack application developer'
#  'biomedical data standards specialist-data collection' 'a.i. specialist'
#  'novice intelligence analyst*' 'fraud analyst' 'head of data science'
#  'growth marketing analyst' 'research analyst senior' 'store assistant'
#  'data scientist (maplewood, mn)' 'material quality engineer'
#  'advanced ai & ml technologies executive'
#  'data and technology program manager' 'actuary' 'cartographer'
#  'data scientist, analyst' 'phone and credential representative, pcs'
#  'data analytics instructor- washington university, st. louis'
#  'biomedical informatician' 'consultant, advanced analytics*'
#  'model risk manager' 'finance consultant' 'field sales manager'
#  'intelligence analyst (counter-insurgency networks)' 'support engineer'
#  'technical consultant / analyst' 'dep epidemiologist'
#  'data intelligence intern'
#  'research scientist, mobile manipulation behaviors'
#  'environmental coordinator' 'lecturer'
#  'quantitative analytics specialist 1' 'engineer i ( electrical engineer)'
#  'faculty awards and programs analyst (7398u) job 2132'
#  'research scientist' 'intern, data science (summer 2020)'
#  'summer scientist intern, content science'
#  'civil society strengthening consultant'
#  'manager, data processing operations' '2020 information technology'
#  'sr data scientist (analytic consultant 5)'
#  'account executive/acute therapies' 'software engineer, data'
#  'stability analyst' 'data strategy lead, data science and ai tech'
#  'data specialist' 'public safety dispatcher i'
#  'network modeling and optimization engineer'
#  'senior member of technical staff, data store and distributed systems'
#  'statistician, biomarkers/genomics (sr. manager)'
#  'software engineer/ computer scientist'
#  'natural language processing scientist' 'cloud engineer'
#  'senior engineering technician' 'salesforce administrator'
#  'manager, business analysis and insights' 'technologist/foundry engineer'
#  'data scientist (mathematical and statistical sciences)'
#  'data scientist and visualization specialist' 'watson health imaging'
#  'data science & tagging analyst'
#  'human resources technician (health care services agency)'
#  'qc lead inspector' 'laboratory assistant ii (9603c)'
#  'project manager w/documentation skills' 'senior engineer (systems)'
#  'systems administrator' 'nesap for learning postdoctoral fellow'
#  'operations analyst i (data analyst)' 'director, client solutions'
#  'associate software engineer' 'lead of genomics ai'
#  'critical targeting network analyst 2' 'hr specialist'
#  'engineer reliability_san diego or palmdale'
#  'database specialist/compliance monitor'
#  'project associate (data analyst)' 'vp, data science'
#  'data scientist, coreapp' 'postdoctoral research fellow'
#  'nosql database administrator' 'research data analyst 2 (6256u) 1789'
#  'speech, language and hearing sciences'
#  'modeling and simulation engineer' 'environmental compliance coordinator'
#  'data science software engineer' 'customer success manager'
#  'data analytics and insights specialist' 'programmer/bioinformatician'
#  'web development teaching assistant' 'director of analytics'
#  'natural language processing expert' 'vp, ai and machine learning'
#  'director of language engineering'
#  "adjunct associate faculty, applied text & natural language (on-campus, spring '20)"
#  'humanities librarian' 'data scientist (sas / r programmer'
#  'entry level accenture consulting development program analyst'
#  'transit service development specialist i'
#  'senior machine learning engineer/ data scientist'
#  'sr. a&p technician customer support usa'
#  'manager/sr. manager, bioinformatics' 'software developer'
#  'tenure-track and tenured faculty positions in artificial intelligence (ai)'
#  'senior research associate' 'machine learning engineering intern'
#  'data scientist (full time)'
#  'financial advisory, valuation services senior associate'
#  'sales analytics lead'
#  'research assistant in data analytics and natural language processing'
#  'financial analyst' 'data science & analytics internship'
#  'data science & analytics intern' 'sr. director'
#  'ecommerce data science analyst'
#  'research intern, machine learning (phd university student)'
#  'cna float pool full time days' 'account executive' 'unix adminstrator'
#  'machine learning engineer, pricing' 'data engineer / scientist'
#  'machine learning specialist senior / intermediate'
#  'linguist/language analyst conus/oconus' 'data scientist gs 13/14'
#  'sr. programmer analyst (bhjob22048_627)' 'software developer 3'
#  'manager of engineering' 'data science lead, operations'
#  'manager, applied analytics' 'consumer research manager'
#  'sr.quality engineer' 'quantitative modeler'
#  'data sciences & ai graduate programme' 'director finance'
#  'big data / pyspark engineer' 'senior systems engineer (ssyseng)'
#  'data modeler' 'research intern, bci signal processing (phd)'
#  'vice president, data strategy & analytics'
#  'associate scientist, data science' 'strategy analyst'
#  'data science & analytics analyst' 'senior software engineer'
#  'spring 2020 ai & ml sw engineering co-op/intern'
#  'manager, data science, programming and visualization'
#  'systems engineer principal'
#  'lightweight protective textile materials with superior energy dissipation capabilities'
#  'sap finance' 'cloud data scientist' 'warehouse worker'
#  'user experience researcher north america'
#  'lecturer in statistics and applied probability' 'sr. big data developer'
#  'digital testing and personalization sr. manager' 'manager 2'
#  'epidemiologist coordinator' 'manager of data science'
#  'product analyst, point of sale and customers'
#  'enroll/encounter data steward' 'entry level data scientist'
#  'data science advisor' 'growth and competition analyst'
#  'associate, major projects advisory'
#  'data science & analytics intern (paid)'
#  'research intern, applied research' 'controller'
#  'data science intern (bs / ms)' 'data scientist intern, phd, 2020'
#  'new college grad' 'network developer'
#  'mathematical and statistical scientist*'
#  'decision science manager, media mix modeling']

# %%
def keep_positions(df):
    """
    Keep positions that contain the word "data scientist" or are adjacent to data scientist. 
    """
    df['position'] = df['position'].map(lambda p: p.lower()) # lower case
    roles = ('data scientist', 'data analyst', 'statistical analyst', 
             'quantitative analyst', 'business analyst',
             'data science', 'data consultant', 
             'machine learning', 'data engineer', 'research analyst',
             'business insights analyst', 'quantitative',
             'analyst', 'intellligence', 'natural language processing', 'data',
             'research scientist')
    keep = [p for p in df['position'] if any(role in p for role in roles)]
    return df[[p in keep for p in df['position']]]

# %%
df = keep_positions(df)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 828 entries, 0 to 1336
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   html      828 non-null    object
#  1   position  828 non-null    object
#  2   location  828 non-null    object
#  3   company   123 non-null    object
#  4   jobreq    828 non-null    object
# dtypes: object(5)
# memory usage: 38.8+ KB
# None

# %% [markdown]
# # Remove redundant job postings

# %%
def uniques_only(df):
    """
    Identify html's of job postings whose job requirements are unique.
    """
    seen = []
    out = []
    for row in df.itertuples(index = True):
        if row.jobreq not in seen:
            out.append(row.html)
            seen.append(row.jobreq)
    return out

# %%
df = df[[h in uniques_only(df) for h in df['html']]]
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 754 entries, 0 to 1336
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   html      754 non-null    object
#  1   position  754 non-null    object
#  2   location  754 non-null    object
#  3   company   110 non-null    object
#  4   jobreq    754 non-null    object
# dtypes: object(5)
# memory usage: 35.3+ KB
# None

# %%
df.to_csv('output/data.csv', index = False)
